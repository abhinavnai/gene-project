# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import pandas as pd
import re

# %%
#hyperparameters
batch_size=64
lr=0.001
epochs=100

# %%
#emdeddings
OP_MAP = {
    '+': 'OP_ADD',
    '-': 'OP_SUB',
    '*': 'OP_MUL',
    '/': 'OP_DIV'
}

def tokenize_gep_string(gep_string):
    tokens = []
    for tok in gep_string.split(','):
        tok = tok.strip()
        if tok in OP_MAP:
            tokens.append((OP_MAP[tok], None))
        elif re.match(r'I\d+', tok):
            tokens.append((f'INV_{tok[1:]}', None))
        else:
            tokens.append(('CONST', float(tok)))
    return tokens

def build_vocab(tokenized_strings):
    vocab = {'PAD': 0}
    idx = 1

    for tokens in tokenized_strings:
        for token_type, _ in tokens:
            if token_type not in vocab:
                vocab[token_type] = idx
                idx += 1

    return vocab
def encode_tokens(tokens, vocab, max_len):
    token_ids = []
    num_vals = []
    for token_type, val in tokens:
        token_ids.append(vocab[token_type])
        num_vals.append(val if val is not None else 0.0)

    token_ids = token_ids[:max_len]
    num_vals = num_vals[:max_len]

    pad_len = max_len - len(token_ids)
    token_ids.extend([vocab['PAD']] * pad_len)
    num_vals.extend([0.0] * pad_len)

    return torch.tensor(token_ids), torch.tensor(num_vals, dtype=torch.float)
class GEPEmbedding(nn.Module):
    def __init__(self, vocab_size, max_len, embed_dim=64):
        super().__init__()
        self.embed_dim = embed_dim
        self.token_embed = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        self.const_proj = nn.Linear(1, embed_dim)
        self.pos_embed = nn.Embedding(max_len, embed_dim)

    def forward(self, token_ids, num_vals):
        B, L = token_ids.shape
        tok_emb = self.token_embed(token_ids)
        num_emb = self.const_proj(num_vals.unsqueeze(-1))
        positions = torch.arange(L, device=token_ids.device)
        pos_emb = self.pos_embed(positions).unsqueeze(0)
        return tok_emb + num_emb + pos_emb  # (B, L, D)

# %%
class GEPDataset(Dataset):
    def __init__(self, strings, targets, vocab, max_len):
        self.strings = strings
        self.targets = targets
        self.vocab = vocab
        self.max_len = max_len

    def __len__(self):
        return len(self.strings)

    def __getitem__(self, idx):
        tokens = tokenize_gep_string(self.strings[idx])
        token_ids, num_vals = encode_tokens(tokens, self.vocab, self.max_len)
        return token_ids, num_vals, torch.tensor(self.targets[idx], dtype=torch.float)
df=pd.read_csv("dataset.csv",)
df = df.drop("run_id", axis=1)
df = df.sample(frac=1, random_state=42).reset_index(drop=True)
x=list(df["string"])
y=df[["cost","p_initial_residual"]].values
y_mean = y.mean(axis=0)
y_std = y.std(axis=0)
y_norm = (y - y_mean) / (y_std + 1e-8)
tokenized_all = [tokenize_gep_string(s) for s in x]
vocab = build_vocab(tokenized_all)
MAX_LEN = 64
BATCH_SIZE = 64
dataset = GEPDataset(x, y_norm, vocab, MAX_LEN)
train_size = int(0.7 * len(dataset))
val_size = int(0.15 * len(dataset))
test_size = len(dataset) - train_size - val_size
train_ds, val_ds, test_ds = torch.utils.data.random_split(dataset, [train_size, val_size, test_size])
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE)
test_loader  = DataLoader(test_ds, batch_size=BATCH_SIZE)
y_max=y.max(axis=0)
print(y_max)

# %%
class EncoderDecoder(nn.Module):
    def __init__(self, dim_latent_space, output_dim, input_dim):
        super().__init__()
        self.l1 = nn.Sequential(
            nn.Linear(input_dim, input_dim),
            nn.Dropout(0.1),
            nn.BatchNorm1d(input_dim),
            nn.ReLU()
        )
        self.l2 = nn.Sequential(
            nn.Linear(input_dim, input_dim // 2),
            nn.Dropout(0.1),
            nn.BatchNorm1d(input_dim // 2),
            nn.ReLU()
        )
        self.l3 = nn.Linear(input_dim // 2, dim_latent_space)
        self.l4 = nn.Sequential(
            nn.Linear(dim_latent_space, input_dim // 2),
            nn.Dropout(0.1),
            nn.BatchNorm1d(input_dim // 2),
            nn.ReLU()
        )
        self.l5 = nn.Sequential(
            nn.Linear(input_dim // 2, input_dim),
            nn.Dropout(0.1),
            nn.BatchNorm1d(input_dim),
            nn.ReLU()
        )
        self.l6 = nn.Linear(input_dim, output_dim)

    def forward(self, x):
        l1 = self.l1(x)
        l2 = self.l2(l1)
        latent = self.l3(l2)
        l4 = self.l4(latent)
        l5 = self.l5(l4 )
        l6 = self.l6(l5)
        return l6
class FullModel(nn.Module):
    def __init__(self, vocab_size, max_len, embed_dim=64, dim_latent_space=32, output_dim=2):
        super().__init__()
        self.embedder = GEPEmbedding(vocab_size, max_len, embed_dim)
        # input_dim for MLP = embed_dim (after mean pooling)
        self.mlp = EncoderDecoder(dim_latent_space, output_dim, embed_dim)

    def forward(self, token_ids, num_vals):
        embeddings = self.embedder(token_ids, num_vals)    # (B, L, D)
        pooled = embeddings.mean(dim=1)                    # (B, D)
        return self.mlp(pooled)

# %%
device = torch.device("cpu")
model = FullModel(vocab_size=len(vocab), max_len=MAX_LEN).to(device)
optim=torch.optim.AdamW(model.parameters(),lr=5e-4)
loss_fn=nn.MSELoss()

# %%
loss_t=[]
loss_v=[]
for epoch in range(150):
    model.train()
    total_loss = 0
    for token_ids, num_vals, y_batch in train_loader:
        # Move tensors to CPU (optional, they're already on CPU)
        token_ids = token_ids.to(device)
        num_vals  = num_vals.to(device)
        y_batch   = y_batch.to(device)

        y_pred = model(token_ids, num_vals)
        loss = loss_fn(y_pred, y_batch)

        optim.zero_grad()
        loss.backward()
        optim.step()

        total_loss += loss.item()

    print(f"Epoch {epoch} | Train Loss: {total_loss / len(train_loader):.4f}")
    loss_t.append(total_loss / len(train_loader))
    # Validation
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for token_ids, num_vals, y_batch in val_loader:
            token_ids = token_ids.to(device)
            num_vals  = num_vals.to(device)
            y_batch   = y_batch.to(device)

            y_pred = model(token_ids, num_vals)
            val_loss += loss_fn(y_pred, y_batch).item()

    print(f"Epoch {epoch} | Val Loss: {val_loss / len(val_loader):.4f}")
    loss_v.append(val_loss / len(val_loader))
    model.train()
# Out:
# Epoch 0 | Train Loss: 1.2507
# Epoch 0 | Val Loss: 0.5063
# Epoch 1 | Train Loss: 1.2119
# Epoch 1 | Val Loss: 0.4799
# Epoch 2 | Train Loss: 1.2100
# Epoch 2 | Val Loss: 0.4876
# Epoch 3 | Train Loss: 1.1973
# Epoch 3 | Val Loss: 0.4856
# Epoch 4 | Train Loss: 1.2091
# Epoch 4 | Val Loss: 0.4876
# Epoch 5 | Train Loss: 1.2037
# Epoch 5 | Val Loss: 0.4841
# Epoch 6 | Train Loss: 1.1988
# Epoch 6 | Val Loss: 0.4785
# Epoch 7 | Train Loss: 1.2003
# Epoch 7 | Val Loss: 0.4799
# Epoch 8 | Train Loss: 1.1947
# Epoch 8 | Val Loss: 0.4762
# Epoch 9 | Train Loss: 1.1895
# Epoch 9 | Val Loss: 0.4745
# Epoch 10 | Train Loss: 1.1920
# Epoch 10 | Val Loss: 0.4748
# Epoch 11 | Train Loss: 1.1950
# Epoch 11 | Val Loss: 0.4730
# Epoch 12 | Train Loss: 1.1880
# Epoch 12 | Val Loss: 0.4773
# Epoch 13 | Train Loss: 1.1870
# Epoch 13 | Val Loss: 0.4837
# Epoch 14 | Train Loss: 1.1911
# Epoch 14 | Val Loss: 0.4726
# Epoch 15 | Train Loss: 1.1973
# Epoch 15 | Val Loss: 0.4711
# Epoch 16 | Train Loss: 1.1904
# Epoch 16 | Val Loss: 0.4716
# Epoch 17 | Train Loss: 1.1904
# Epoch 17 | Val Loss: 0.4765
# Epoch 18 | Train Loss: 1.1915
# Epoch 18 | Val Loss: 0.4732
# Epoch 19 | Train Loss: 1.1836
# Epoch 19 | Val Loss: 0.4770
# Epoch 20 | Train Loss: 1.1794
# Epoch 20 | Val Loss: 0.4738
# Epoch 21 | Train Loss: 1.1878
# Epoch 21 | Val Loss: 0.4730
# Epoch 22 | Train Loss: 1.1830
# Epoch 22 | Val Loss: 0.4748
# Epoch 23 | Train Loss: 1.1818
# Epoch 23 | Val Loss: 0.4805
# Epoch 24 | Train Loss: 1.1846
# Epoch 24 | Val Loss: 0.4763
# Epoch 25 | Train Loss: 1.1902
# Epoch 25 | Val Loss: 0.4713
# Epoch 26 | Train Loss: 1.1852
# Epoch 26 | Val Loss: 0.4727
# Epoch 27 | Train Loss: 1.1775
# Epoch 27 | Val Loss: 0.4781
# Epoch 28 | Train Loss: 1.1821
# Epoch 28 | Val Loss: 0.4738
# Epoch 29 | Train Loss: 1.1816
# Epoch 29 | Val Loss: 0.4730
# Epoch 30 | Train Loss: 1.1809
# Epoch 30 | Val Loss: 0.4714
# Epoch 31 | Train Loss: 1.1777
# Epoch 31 | Val Loss: 0.4755
# Epoch 32 | Train Loss: 1.1834
# Epoch 32 | Val Loss: 0.4747
# Epoch 33 | Train Loss: 1.1806
# Epoch 33 | Val Loss: 0.4704
# Epoch 34 | Train Loss: 1.1815
# Epoch 34 | Val Loss: 0.4723
# Epoch 35 | Train Loss: 1.1766
# Epoch 35 | Val Loss: 0.4730
# Epoch 36 | Train Loss: 1.1868
# Epoch 36 | Val Loss: 0.4740
# Epoch 37 | Train Loss: 1.1832
# Epoch 37 | Val Loss: 0.4771
# Epoch 38 | Train Loss: 1.1803
# Epoch 38 | Val Loss: 0.4722
# Epoch 39 | Train Loss: 1.1794
# Epoch 39 | Val Loss: 0.4722
# Epoch 40 | Train Loss: 1.1828
# Epoch 40 | Val Loss: 0.4753
# Epoch 41 | Train Loss: 1.1807
# Epoch 41 | Val Loss: 0.4704
# Epoch 42 | Train Loss: 1.1810
# Epoch 42 | Val Loss: 0.4707
# Epoch 43 | Train Loss: 1.1751
# Epoch 43 | Val Loss: 0.4730
# Epoch 44 | Train Loss: 1.1793
# Epoch 44 | Val Loss: 0.4700
# Epoch 45 | Train Loss: 1.1794
# Epoch 45 | Val Loss: 0.4753
# Epoch 46 | Train Loss: 1.1810
# Epoch 46 | Val Loss: 0.4705
# Epoch 47 | Train Loss: 1.1764
# Epoch 47 | Val Loss: 0.4706
# Epoch 48 | Train Loss: 1.1802
# Epoch 48 | Val Loss: 0.4711
# Epoch 49 | Train Loss: 1.1796
# Epoch 49 | Val Loss: 0.4743
# Epoch 50 | Train Loss: 1.1803
# Epoch 50 | Val Loss: 0.4784
# Epoch 51 | Train Loss: 1.1812
# Epoch 51 | Val Loss: 0.4746
# Epoch 52 | Train Loss: 1.1783
# Epoch 52 | Val Loss: 0.4825
# Epoch 53 | Train Loss: 1.1797
# Epoch 53 | Val Loss: 0.4718
# Epoch 54 | Train Loss: 1.1792
# Epoch 54 | Val Loss: 0.4704
# Epoch 55 | Train Loss: 1.1763
# Epoch 55 | Val Loss: 0.4698
# Epoch 56 | Train Loss: 1.1744
# Epoch 56 | Val Loss: 0.4709
# Epoch 57 | Train Loss: 1.1748
# Epoch 57 | Val Loss: 0.4712
# Epoch 58 | Train Loss: 1.1810
# Epoch 58 | Val Loss: 0.4770
# Epoch 59 | Train Loss: 1.1763
# Epoch 59 | Val Loss: 0.4683
# Epoch 60 | Train Loss: 1.1713
# Epoch 60 | Val Loss: 0.4717
# Epoch 61 | Train Loss: 1.1777
# Epoch 61 | Val Loss: 0.4711
# Epoch 62 | Train Loss: 1.1747
# Epoch 62 | Val Loss: 0.4763
# Epoch 63 | Train Loss: 1.1724
# Epoch 63 | Val Loss: 0.4721
# Epoch 64 | Train Loss: 1.1750
# Epoch 64 | Val Loss: 0.4696
# Epoch 65 | Train Loss: 1.1768
# Epoch 65 | Val Loss: 0.4731
# Epoch 66 | Train Loss: 1.1762
# Epoch 66 | Val Loss: 0.4740
# Epoch 67 | Train Loss: 1.1712
# Epoch 67 | Val Loss: 0.4756
# Epoch 68 | Train Loss: 1.1798
# Epoch 68 | Val Loss: 0.4746
# Epoch 69 | Train Loss: 1.1742
# Epoch 69 | Val Loss: 0.4714
# Epoch 70 | Train Loss: 1.1730
# Epoch 70 | Val Loss: 0.4726
# Epoch 71 | Train Loss: 1.1836
# Epoch 71 | Val Loss: 0.4738
# Epoch 72 | Train Loss: 1.1775
# Epoch 72 | Val Loss: 0.4696
# Epoch 73 | Train Loss: 1.1725
# Epoch 73 | Val Loss: 0.4714
# Epoch 74 | Train Loss: 1.1760
# Epoch 74 | Val Loss: 0.4745
# Epoch 75 | Train Loss: 1.1719
# Epoch 75 | Val Loss: 0.4694
# Epoch 76 | Train Loss: 1.1761
# Epoch 76 | Val Loss: 0.4710
# Epoch 77 | Train Loss: 1.1667
# Epoch 77 | Val Loss: 0.4702
# Epoch 78 | Train Loss: 1.1817
# Epoch 78 | Val Loss: 0.4685
# Epoch 79 | Train Loss: 1.1655
# Epoch 79 | Val Loss: 0.4712
# Epoch 80 | Train Loss: 1.1695
# Epoch 80 | Val Loss: 0.4693
# Epoch 81 | Train Loss: 1.1765
# Epoch 81 | Val Loss: 0.4772
# Epoch 82 | Train Loss: 1.1695
# Epoch 82 | Val Loss: 0.4701
# Epoch 83 | Train Loss: 1.1754
# Epoch 83 | Val Loss: 0.4691
# Epoch 84 | Train Loss: 1.1693
# Epoch 84 | Val Loss: 0.4686
# Epoch 85 | Train Loss: 1.1753
# Epoch 85 | Val Loss: 0.4711
# Epoch 86 | Train Loss: 1.1714
# Epoch 86 | Val Loss: 0.4703
# Epoch 87 | Train Loss: 1.1742
# Epoch 87 | Val Loss: 0.4718
# Epoch 88 | Train Loss: 1.1716
# Epoch 88 | Val Loss: 0.4751
# Epoch 89 | Train Loss: 1.1688
# Epoch 89 | Val Loss: 0.4756
# Epoch 90 | Train Loss: 1.1725
# Epoch 90 | Val Loss: 0.4881
# Epoch 91 | Train Loss: 1.1671
# Epoch 91 | Val Loss: 0.4736
# Epoch 92 | Train Loss: 1.1775
# Epoch 92 | Val Loss: 0.4759
# Epoch 93 | Train Loss: 1.1751
# Epoch 93 | Val Loss: 0.4708
# Epoch 94 | Train Loss: 1.1656
# Epoch 94 | Val Loss: 0.4708
# Epoch 95 | Train Loss: 1.1647
# Epoch 95 | Val Loss: 0.4777
# Epoch 96 | Train Loss: 1.1644
# Epoch 96 | Val Loss: 0.4693
# Epoch 97 | Train Loss: 1.1703
# Epoch 97 | Val Loss: 0.4765
# Epoch 98 | Train Loss: 1.1610
# Epoch 98 | Val Loss: 0.4813
# Epoch 99 | Train Loss: 1.1713
# Epoch 99 | Val Loss: 0.4772
# Epoch 100 | Train Loss: 1.1632
# Epoch 100 | Val Loss: 0.4752
# Epoch 101 | Train Loss: 1.1710
# Epoch 101 | Val Loss: 0.4756
# Epoch 102 | Train Loss: 1.1727
# Epoch 102 | Val Loss: 0.4792
# Epoch 103 | Train Loss: 1.1581
# Epoch 103 | Val Loss: 0.4922
# Epoch 104 | Train Loss: 1.1708
# Epoch 104 | Val Loss: 0.5272
# Epoch 105 | Train Loss: 1.1628
# Epoch 105 | Val Loss: 0.4846
# Epoch 106 | Train Loss: 1.1621
# Epoch 106 | Val Loss: 0.4733
# Epoch 107 | Train Loss: 1.1707
# Epoch 107 | Val Loss: 0.4742
# Epoch 108 | Train Loss: 1.1708
# Epoch 108 | Val Loss: 0.4755
# Epoch 109 | Train Loss: 1.1646
# Epoch 109 | Val Loss: 0.4810
# Epoch 110 | Train Loss: 1.1602
# Epoch 110 | Val Loss: 0.4787
# Epoch 111 | Train Loss: 1.1539
# Epoch 111 | Val Loss: 0.4814
# Epoch 112 | Train Loss: 1.1622
# Epoch 112 | Val Loss: 0.4992
# Epoch 113 | Train Loss: 1.1583
# Epoch 113 | Val Loss: 0.4714
# Epoch 114 | Train Loss: 1.1638
# Epoch 114 | Val Loss: 0.4805
# Epoch 115 | Train Loss: 1.1534
# Epoch 115 | Val Loss: 0.4737
# Epoch 116 | Train Loss: 1.1515
# Epoch 116 | Val Loss: 0.4947
# Epoch 117 | Train Loss: 1.1634
# Epoch 117 | Val Loss: 0.4961
# Epoch 118 | Train Loss: 1.1686
# Epoch 118 | Val Loss: 0.4779
# Epoch 119 | Train Loss: 1.1595
# Epoch 119 | Val Loss: 0.4807
# Epoch 120 | Train Loss: 1.1521
# Epoch 120 | Val Loss: 0.4910
# Epoch 121 | Train Loss: 1.1646
# Epoch 121 | Val Loss: 0.4761
# Epoch 122 | Train Loss: 1.1562
# Epoch 122 | Val Loss: 0.4841
# Epoch 123 | Train Loss: 1.1532
# Epoch 123 | Val Loss: 0.4931
# Epoch 124 | Train Loss: 1.1712
# Epoch 124 | Val Loss: 0.4857
# Epoch 125 | Train Loss: 1.1592
# Epoch 125 | Val Loss: 0.5669
# Epoch 126 | Train Loss: 1.1606
# Epoch 126 | Val Loss: 0.4835
# Epoch 127 | Train Loss: 1.1738
# Epoch 127 | Val Loss: 0.4984
# Epoch 128 | Train Loss: 1.1559
# Epoch 128 | Val Loss: 0.4933
# Epoch 129 | Train Loss: 1.1396
# Epoch 129 | Val Loss: 0.4805
# Epoch 130 | Train Loss: 1.1560
# Epoch 130 | Val Loss: 0.4763
# Epoch 131 | Train Loss: 1.1460
# Epoch 131 | Val Loss: 0.4819
# Epoch 132 | Train Loss: 1.1440
# Epoch 132 | Val Loss: 0.5556
# Epoch 133 | Train Loss: 1.1485
# Epoch 133 | Val Loss: 0.5162
# Epoch 134 | Train Loss: 1.1298
# Epoch 134 | Val Loss: 0.4859
# Epoch 135 | Train Loss: 1.1259
# Epoch 135 | Val Loss: 0.4813
# Epoch 136 | Train Loss: 1.1690
# Epoch 136 | Val Loss: 0.4854
# Epoch 137 | Train Loss: 1.1684
# Epoch 137 | Val Loss: 0.4903
# Epoch 138 | Train Loss: 1.1419
# Epoch 138 | Val Loss: 0.4829
# Epoch 139 | Train Loss: 1.1800
# Epoch 139 | Val Loss: 0.4919
# Epoch 140 | Train Loss: 1.1454
# Epoch 140 | Val Loss: 0.5141
# Epoch 141 | Train Loss: 1.1572
# Epoch 141 | Val Loss: 0.5088
# Epoch 142 | Train Loss: 1.1516
# Epoch 142 | Val Loss: 0.4942
# Epoch 143 | Train Loss: 1.1621
# Epoch 143 | Val Loss: 0.5776
# Epoch 144 | Train Loss: 1.1481
# Epoch 144 | Val Loss: 0.4751
# Epoch 145 | Train Loss: 1.1751
# Epoch 145 | Val Loss: 0.4862
# Epoch 146 | Train Loss: 1.1581
# Epoch 146 | Val Loss: 0.4909
# Epoch 147 | Train Loss: 1.1360
# Epoch 147 | Val Loss: 0.5187
# Epoch 148 | Train Loss: 1.1176
# Epoch 148 | Val Loss: 0.4856
# Epoch 149 | Train Loss: 1.1450
# Epoch 149 | Val Loss: 0.5197

# %%
import matplotlib.pyplot as plt
plt.plot(loss_t, label="Training Loss")
plt.plot(loss_v, label="Validation Loss")
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
loss_t = []

model.eval()
with torch.no_grad():
    for token_ids, num_vals, y_batch in test_loader:
        token_ids = token_ids.to(device)
        num_vals  = num_vals.to(device)
        y_batch   = y_batch.to(device)

        y_pred = model(token_ids, num_vals)
        loss = loss_fn(y_pred, y_batch)
        loss_t.append(loss.item())  # append per-batch loss

# Plotting
plt.figure(figsize=(8,5))
plt.plot(loss_t, label="Test Loss per Batch")
plt.xlabel("Batch Index")
plt.ylabel("Loss")
plt.title("Test Loss over Batches")
plt.legend()
plt.show()

# %%
from torch.utils.data import DataLoader, Subset

# Take first 5 samples safely
dataset_example = Subset(dataset, range(5))

y_pred_examples = []
y_real = []

model.eval()
with torch.no_grad():
    for token_ids, num_vals, y_batch in DataLoader(dataset_example, batch_size=5):
        token_ids = token_ids.to(device)
        num_vals  = num_vals.to(device)
        y_batch   = y_batch.to(device)

        # Forward pass
        y_pred = model(token_ids, num_vals)

        # Denormalize
        y_pred = y_pred * (y_std + 1e-8) + y_mean
        y_batch = y_batch * (y_std + 1e-8) + y_mean

        y_pred_examples.append(y_pred.cpu())
        y_real.append(y_batch.cpu())

# Print nicely
print("Predicted vs Real:")
for yp, yr in zip(y_pred_examples[0], y_real[0]):
    print(f"Predicted: {yp.numpy()} | Real: {yr.numpy()}")
# Out:
# Predicted vs Real:
# Predicted: [2.39757046e+76 6.49455816e-02] | Real: [-3.24938903e+68  3.77327006e-01]
# Predicted: [6.88419382e+77 1.07638843e-01] | Real: [-3.24938903e+68  3.10638005e-02]
# Predicted: [-5.66482856e+77  1.35810112e-01] | Real: [-3.24938903e+68  5.55523988e-01]
# Predicted: [7.84905579e+77 2.08346441e-01] | Real: [-3.24938903e+68  1.68168012e-02]
# Predicted: [-5.55964523e+77  1.49288583e-01] | Real: [-3.24938903e+68  1.24844000e-01]
# C:\Users\asus\AppData\Local\Temp\ipykernel_32952\3000641300.py:20: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   y_pred = y_pred * (y_std + 1e-8) + y_mean
# C:\Users\asus\AppData\Local\Temp\ipykernel_32952\3000641300.py:21: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   y_batch = y_batch * (y_std + 1e-8) + y_mean

# %%
y_pred_all = torch.cat(y_pred_examples, dim=0).numpy()
y_real_all = torch.cat(y_real, dim=0).numpy()

# Split into cost and p
pred_cost = y_pred_all[:, 0]
pred_p    = y_pred_all[:, 1]

real_cost = y_real_all[:, 0]
real_p    = y_real_all[:, 1]
plt.figure()
plt.plot(real_cost, label="Real Cost", marker="o")
plt.plot(pred_cost, label="Predicted Cost", marker="x")
plt.xlabel("Sample index")
plt.ylabel("Cost")
plt.title("Cost: Predicted vs Real")
plt.legend()
plt.grid(True)
plt.show()
plt.figure()
plt.plot(real_p, label="Real p_initial_residual", marker="o")
plt.plot(pred_p, label="Predicted p_initial_residual", marker="x")
plt.xlabel("Sample index")
plt.ylabel("p_initial_residual")
plt.title("p_initial_residual: Predicted vs Real")
plt.legend()
plt.grid(True)
plt.show()
